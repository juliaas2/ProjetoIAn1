# %%
import pandas as pd

# Definindo os dados
dados = {
    "Algoritmo": [],
    "Objetivo": [],
    "Tempo de processamento": []
}


# Criando o DataFrame

# %%
from aigyminsper.search.SearchAlgorithms import BuscaLargura
from aigyminsper.search.SearchAlgorithms import BuscaProfundidade
from aigyminsper.search.SearchAlgorithms import BuscaProfundidadeIterativa
from aigyminsper.search.Graph import State
from datetime import datetime

class SumOne(State):

    def __init__(self, n, op, g):
        self.operator = op
        self.number = n
        self.goal = g

    def successors(self):
        sucessors = []
        if self.number < self.goal:
            sucessors.append(SumOne(self.number+1, "+1 ", self.goal))
            sucessors.append(SumOne(self.number+2, "+2 ", self.goal))
        return sucessors

    def is_goal(self):
        if self.goal == self.number:
            return True
        return False

    def description(self):
        return "Este é um agente simples que sabe somar 1 e 2"

    def cost(self):
        return 1

    def env(self):
        return self.number

def main():
    for objetivo in range(1, 47):  # Vai de 1 a 50
        state = SumOne(1, '', objetivo)
        algorithm = BuscaLargura()  # Você pode trocar o algoritmo aqui conforme necessário
        dados["Algoritmo"].append("Busca em Largura")
        dados["Objetivo"].append(objetivo)
        # algorithm = BuscaProfundidade()
        # algorithm = BuscaProfundidadeIterativa()
        start_time = datetime.now()
        result = algorithm.search(state)
        end_time = datetime.now()
        Tempo_de_processamento = str(end_time - start_time)
        print(f'Objetivo: {objetivo}, Tempo de processamento = {end_time - start_time}')

        if result is not None:
            print('Achou!')
            dados["Tempo de processamento"].append(Tempo_de_processamento)
            print(result.show_path())
        else:
            dados["Tempo de processamento"].append("Não achou")
            print('Nao achou solucao')

if __name__ == '__main__':
    main()
# Out:
# Objetivo: 1, Tempo de processamento = 0:00:00
# Achou!
#
# Objetivo: 2, Tempo de processamento = 0:00:00
# Achou!
#  ; +1
# Objetivo: 3, Tempo de processamento = 0:00:00
# Achou!
#  ; +2
# Objetivo: 4, Tempo de processamento = 0:00:00
# Achou!
#  ; +1  ; +2
# Objetivo: 5, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2
# Objetivo: 6, Tempo de processamento = 0:00:00
# Achou!
#  ; +1  ; +2  ; +2
# Objetivo: 7, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +2
# Objetivo: 8, Tempo de processamento = 0:00:00
# Achou!
#  ; +1  ; +2  ; +2  ; +2
# Objetivo: 9, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +2  ; +2
# Objetivo: 10, Tempo de processamento = 0:00:00
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2
# Objetivo: 11, Tempo de processamento = 0:00:00.000998
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2
# Objetivo: 12, Tempo de processamento = 0:00:00
# Achou!
#  ; +1  ; +2  ; +2  ; +2  ; +2  ; +2
# Objetivo: 13, Tempo de processamento = 0:00:00
# Achou!
# ...

# %%
from aigyminsper.search.SearchAlgorithms import BuscaLargura
from aigyminsper.search.SearchAlgorithms import BuscaProfundidade
from aigyminsper.search.SearchAlgorithms import BuscaProfundidadeIterativa
from aigyminsper.search.Graph import State
from datetime import datetime

class SumOne(State):

    def __init__(self, n, op, g):
        self.operator = op
        self.number = n
        self.goal = g

    def successors(self):
        sucessors = []
        if self.number < self.goal:
            sucessors.append(SumOne(self.number+1, "+1 ", self.goal))
            sucessors.append(SumOne(self.number+2, "+2 ", self.goal))
        return sucessors

    def is_goal(self):
        if self.goal == self.number:
            return True
        return False

    def description(self):
        return "Este é um agente simples que sabe somar 1 e 2"

    def cost(self):
        return 1

    def env(self):
        return self.number

def main():
    for objetivo in range(1, 51):  # Vai de 1 a 50
        state = SumOne(1, '', objetivo)
          # Você pode trocar o algoritmo aqui conforme necessário
        dados["Algoritmo"].append("Busca em Profundidade com m= 10")
        dados["Objetivo"].append(objetivo)
        algorithm = BuscaProfundidade()
        # algorithm = BuscaProfundidadeIterativa()
        start_time = datetime.now()
        result = algorithm.search(state, trace= True, m=10)
        end_time = datetime.now()
        Tempo_de_processamento = str(end_time - start_time)

        print(f'Objetivo: {objetivo}, Tempo de processamento = {end_time - start_time}')
        if result is not None:
            print('Achou!')
            dados["Tempo de processamento"].append(Tempo_de_processamento)
            print(result.show_path())
        else:
            dados["Tempo de processamento"].append("Não achou")
            print('Nao achou solucao')

if __name__ == '__main__':
    main()
# Out:
# Estado = 1 com custo = 0
# Objetivo: 1, Tempo de processamento = 0:00:00
# Achou!
#
# Estado = 1 com custo = 0
# Estado = 3 com custo = 1
# Estado = 2 com custo = 1
# Objetivo: 2, Tempo de processamento = 0:00:00
# Achou!
#  ; +1
# Estado = 1 com custo = 0
# Estado = 3 com custo = 1
# Objetivo: 3, Tempo de processamento = 0:00:00
# Achou!
#  ; +2
# Estado = 1 com custo = 0
# Estado = 3 com custo = 1
# Estado = 5 com custo = 2
# Estado = 4 com custo = 2
# Objetivo: 4, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +1
# Estado = 1 com custo = 0
# Estado = 3 com custo = 1
# Estado = 5 com custo = 2
# Objetivo: 5, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2
# Estado = 1 com custo = 0
# Estado = 3 com custo = 1
# Estado = 5 com custo = 2
# Estado = 7 com custo = 3
# Estado = 6 com custo = 3
# Objetivo: 6, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +1
# Estado = 1 com custo = 0
# Estado = 3 com custo = 1
# Estado = 5 com custo = 2
# ...

# %%
class SumOne(State):

    def __init__(self, n, op, g):
        self.operator = op
        self.number = n
        self.goal = g

    def successors(self):
        sucessors = []
        if self.number < self.goal:
            sucessors.append(SumOne(self.number+1, "+1 ", self.goal))
            sucessors.append(SumOne(self.number+2, "+2 ", self.goal))
        return sucessors

    def is_goal(self):
        if self.goal == self.number:
            return True
        return False

    def description(self):
        return "Este é um agente simples que sabe somar 1 e 2"

    def cost(self):
        return 1

    def env(self):
        return self.number

def main():
    for objetivo in range(1, 51):  # Vai de 1 a 50
        state = SumOne(1, '', objetivo)
          # Você pode trocar o algoritmo aqui conforme necessário
        dados["Algoritmo"].append("Busca em Profundidade com m= 100")
        dados["Objetivo"].append(objetivo)
        algorithm = BuscaProfundidade()
        # algorithm = BuscaProfundidadeIterativa()
        start_time = datetime.now()
        result = algorithm.search(state, trace= True, m=100)
        end_time = datetime.now()
        Tempo_de_processamento = str(end_time - start_time)
        print(f'Objetivo: {objetivo}, Tempo de processamento = {end_time - start_time}')

        if result is not None:
            print('Achou!')
            dados["Tempo de processamento"].append(Tempo_de_processamento)
            print(result.show_path())
        else:
            dados["Tempo de processamento"].append("Não achou")
            print('Nao achou solucao')

if __name__ == '__main__':
    main()
# Out:
# Estado = 1 com custo = 0
# Objetivo: 1, Tempo de processamento = 0:00:00
# Achou!
#
# Estado = 1 com custo = 0
# Estado = 3 com custo = 1
# Estado = 2 com custo = 1
# Objetivo: 2, Tempo de processamento = 0:00:00
# Achou!
#  ; +1
# Estado = 1 com custo = 0
# Estado = 3 com custo = 1
# Objetivo: 3, Tempo de processamento = 0:00:00
# Achou!
#  ; +2
# Estado = 1 com custo = 0
# Estado = 3 com custo = 1
# Estado = 5 com custo = 2
# Estado = 4 com custo = 2
# Objetivo: 4, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +1
# Estado = 1 com custo = 0
# Estado = 3 com custo = 1
# Estado = 5 com custo = 2
# Objetivo: 5, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2
# Estado = 1 com custo = 0
# Estado = 3 com custo = 1
# Estado = 5 com custo = 2
# Estado = 7 com custo = 3
# Estado = 6 com custo = 3
# Objetivo: 6, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +1
# Estado = 1 com custo = 0
# Estado = 3 com custo = 1
# Estado = 5 com custo = 2
# ...

# %%
class SumOne(State):

    def __init__(self, n, op, g):
        self.operator = op
        self.number = n
        self.goal = g

    def successors(self):
        sucessors = []
        if self.number < self.goal:
            sucessors.append(SumOne(self.number+1, "+1 ", self.goal))
            sucessors.append(SumOne(self.number+2, "+2 ", self.goal))
        return sucessors

    def is_goal(self):
        if self.goal == self.number:
            return True
        return False

    def description(self):
        return "Este é um agente simples que sabe somar 1 e 2"

    def cost(self):
        return 1

    def env(self):
        return self.number

def main():
    for objetivo in range(1, 51):  # Vai de 1 a 50
        state = SumOne(1, '', objetivo)
          # Você pode trocar o algoritmo aqui conforme necessário
        dados["Algoritmo"].append("Busca em Profundidade Iterativa")
        dados["Objetivo"].append(objetivo)
        algorithm = BuscaProfundidadeIterativa()
        start_time = datetime.now()
        result = algorithm.search(state)
        end_time = datetime.now()
        Tempo_de_processamento = str(end_time - start_time)
        print(f'Objetivo: {objetivo}, Tempo de processamento = {end_time - start_time}')
        if result is not None:
            print('Achou!')
            dados["Tempo de processamento"].append(Tempo_de_processamento)
            print(result.show_path())
        else:
            dados["Tempo de processamento"].append("Não achou")
            print('Nao achou solucao')

if __name__ == '__main__':
    main()
# Out:
# Objetivo: 1, Tempo de processamento = 0:00:00
# Achou!
#
# Objetivo: 2, Tempo de processamento = 0:00:00
# Achou!
#  ; +1
# Objetivo: 3, Tempo de processamento = 0:00:00
# Achou!
#  ; +2
# Objetivo: 4, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +1
# Objetivo: 5, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2
# Objetivo: 6, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +1
# Objetivo: 7, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +2
# Objetivo: 8, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +2  ; +1
# Objetivo: 9, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +2  ; +2
# Objetivo: 10, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +1
# Objetivo: 11, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2
# Objetivo: 12, Tempo de processamento = 0:00:00
# Achou!
#  ; +2  ; +2  ; +2  ; +2  ; +2  ; +1
# Objetivo: 13, Tempo de processamento = 0:00:00
# Achou!
# ...

# %%
import pandas as pd
df = pd.DataFrame(dados)
import matplotlib.pyplot as plt
df_head = df.head(197)
from pandas.plotting import table

# Criar uma figura e um eixo no matplotlib
fig, ax = plt.subplots(figsize=(25, 10))  # Ajuste o tamanho conforme necessário

# Esconder os eixos
ax.axis('off')

# Criar a tabela usando o DataFrame
tbl = table(ax, df_head, loc='center', cellLoc='center', colWidths=[0.2]*len(df.columns))

# Ajustar o layout
plt.tight_layout()

# Salvar a figura. A extensão do arquivo determina o tipo da imagem (por exemplo, png, jpg, etc.)
plt.savefig("C:\\Users\\Julia\\facul\\ProjetoIAn1\\ur\\uou.png")

# Mostrar a figura se desejar visualizá-la aqui
plt.show()
# Out:
# C:\Users\Julia\AppData\Local\Temp\ipykernel_2972\1803226083.py:17: UserWarning:
#
# Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.

# %%
import pandas as pd
import plotly.graph_objects as go

# Suponha que seu DataFrame seja chamado df

# Função para converter tempo de string para segundos
def tempo_para_segundos(tempo_str):
    if tempo_str == 'Não achou':
        return None
    # Verifica se tempo_str é realmente uma string
    if isinstance(tempo_str, str):
        horas, minutos, segundos = map(float, tempo_str.split(':'))
        return horas * 3600 + minutos * 60 + segundos

# Processamento dos dados
df['Tempo de Processamento (s)'] = df['Tempo de processamento'].apply(lambda x: tempo_para_segundos(x))

# Ordenando os algoritmos
algoritmos = [
    "Busca em Largura",
    "Busca em Profundidade Iterativa",
    "Busca em Profundidade com m= 100",
    "Busca em Profundidade com m= 10"
]

# Filtrando os algoritmos que têm resultado
df_resultados = df[df['Tempo de processamento'] != 'Não achou']

# Criando o gráfico
fig = go.Figure()

for algoritmo in algoritmos:
    dados_algoritmo = df_resultados[df_resultados['Algoritmo'] == algoritmo]
    fig.add_trace(go.Scatter(x=dados_algoritmo['Objetivo'], y=dados_algoritmo['Tempo de Processamento (s)'],
                             mode='lines+markers', name=algoritmo))

# Configurando layout
fig.update_layout(title='Tempo de Processamento por Algoritmo',
                  xaxis_title='Objetivo',
                  yaxis_title='Tempo de Processamento (segundos)',
                  legend_title='Algoritmo')

# Salvando o gráfico em um arquivo HTML
fig.write_html("tempo_processamento.html")
